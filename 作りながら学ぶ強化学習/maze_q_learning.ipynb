# %% [markdown]
# # SarsaとQ学習の定性的な違い
# Sarsaは行動価値関数Qの更新に次の行動at+1を使用するため、行動価値関数の更新がat+1を求める方策（ε-greedy法）のパラメータ ε に依存するという特徴があります。このような特性を方策オン型と呼びます。そのため、ε を計画的に減らすなどしないと行動価値関数がきちんと学習できません。
#
# 一方でQ学習は行動価値関数Qの更新にε-greedy法のパラメータεなど行動決定方法（方策）は依存しません。このような特性を方策オフ型と呼びます。ε-greedy法から生まれるランダム性が更新式に入らない分、行動価値関数の収束がSarsaよりも早いという特徴があります。
#
# とはいえQ学習にε-greedy法が関係ないわけではなく、Sarsaと同じく方策の決定にはε-greedy法を使用します。そうしないと、例えば迷路であれば常に現在の行動価値関数が最大の方向へしか移動せず、未知の状態を探索してくれないからです。ですがSarsaのときのようにパラメータ ε を試行数（エピソード数）に従って小さく変化させなくても、Q学習は最適な方策価値関数に落ち着くことが示されています[1]。
#
# 結局SarsaとQ学習のどちらの方が良い手法なのかは実は行動価値関数の更新と、方策のε-greedy法のパラメータの組み合わせで決まるため、確定的にこちらがおすすめですとは証明されてはいないようです。

# %%
# Jupyterでmatplotlibを使用する宣言と、使用するライブラリの定義
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# 初期位置での迷路の様子

# 図を描く大きさと、図の変数名を宣言
fig = plt.figure(figsize=(5, 5))
ax = plt.gca()

# 赤い壁を描く
plt.plot([1, 1], [0, 1], color='red', linewidth=2)
plt.plot([1, 2], [2, 2], color='red', linewidth=2)
plt.plot([2, 2], [2, 1], color='red', linewidth=2)
plt.plot([2, 3], [1, 1], color='red', linewidth=2)

# 状態を示す文字S0～S8を描く
plt.text(0.5, 2.5, 'S0', size=14, ha='center')
plt.text(1.5, 2.5, 'S1', size=14, ha='center')
plt.text(2.5, 2.5, 'S2', size=14, ha='center')
plt.text(0.5, 1.5, 'S3', size=14, ha='center')
plt.text(1.5, 1.5, 'S4', size=14, ha='center')
plt.text(2.5, 1.5, 'S5', size=14, ha='center')
plt.text(0.5, 0.5, 'S6', size=14, ha='center')
plt.text(1.5, 0.5, 'S7', size=14, ha='center')
plt.text(2.5, 0.5, 'S8', size=14, ha='center')
plt.text(0.5, 2.3, 'START', ha='center')
plt.text(2.5, 0.3, 'GOAL', ha='center')

# 描画範囲の設定と目盛りを消す設定
ax.set_xlim(0, 3)
ax.set_ylim(0, 3)
plt.tick_params(axis='both', which='both', bottom='off', top='off',
                labelbottom='off', right='off', left='off', labelleft='off')

# 現在値S0に緑丸を描画する
line, = ax.plot([0.5], [2.5], marker="o", color='g', markersize=60)

plt.show()

# %%
# 初期の方策を決定するパラメータtheta_0を設定
# 行は状態0～7、列は移動方向で↑、→、↓、←を表す
theta_0 = np.array([[np.nan, 1, 1, np.nan],  # s0
                    [np.nan, 1, np.nan, 1],  # s1
                    [np.nan, np.nan, 1, 1],  # s2
                    [1, 1, 1, np.nan],  # s3
                    [np.nan, np.nan, 1, 1],  # s4
                    [1, np.nan, np.nan, np.nan],  # s5
                    [1, np.nan, np.nan, np.nan],  # s6
                    [1, 1, np.nan, np.nan],  # s7、※s8はゴールなので、方策はなし
                    ])


# 初期の行動価値関数Qを設定
[a, b] = theta_0.shape  # 行と列の数をa, bに格納
Q = np.random.rand(a, b) * theta_0
# *theta0をすることで要素ごとに掛け算をし、壁方向がnanになる

# %% [markdown]
# # 方策をε-greedy

# %%
# 方策パラメータtheta_0をランダム方策piに変換する関数の定義
def simple_convert_into_pi_from_theta(theta):
    '''単純に割合を計算する'''
 
    [m, n] = theta.shape  # thetaの行列サイズを取得
    pi = np.zeros((m, n))
    for i in range(0, m):
        pi[i, :] = theta[i, :] / np.nansum(theta[i, :])  # 割合の計算
 
    pi = np.nan_to_num(pi)  # nanを0に変換
 
    return pi
 
# ランダム行動方策pi_0を求める
pi_0 = simple_convert_into_pi_from_theta(theta_0)

# ε-greedy法を実装
def get_action_and_s_next(s, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]
 
    # 行動を決める
    if np.random.rand() < epsilon:
        # εの確率でランダムに動く
        next_direction = np.random.choice(direction, p=pi_0[s, :])
    else:
        # Qの最大値の行動を採用する
        next_direction = direction[np.nanargmax(Q[s, :])]
 
    # 決めた行動で次の状態を決める
    if next_direction == "up":
        action = 0
        s_next = s - 3  # 上に移動するときは状態の数字が3小さくなる
    elif next_direction == "right":
        action = 1
        s_next = s + 1  # 右に移動するときは状態の数字が1大きくなる
    elif next_direction == "down":
        action = 2
        s_next = s + 3  # 下に移動するときは状態の数字が3大きくなる
    elif next_direction == "left":
        action = 3
        s_next = s - 1  # 左に移動するときは状態の数字が1小さくなる
 
    return [action, s_next]

# %% [markdown]
# # Q-learning

# %%
# Q学習による行動価値関数Qの更新
def Q_learning(s, a, r, s_next, Q, eta, gamma):
 
    if s_next == 8:  # ゴールした場合
        Q[s, a] = Q[s, a] + eta * (r - Q[s, a])
 
    else:
        Q[s, a] = Q[s, a] + eta * (r + gamma * np.nanmax(Q[s_next,: ]) - Q[s, a])
        #Q[s, a] = Q[s, a] + eta * (r + gamma * Q[s_next, a_next] - Q[s, a])
 
    return Q

# %%
# Q学習で迷路を解く関数の定義、状態と行動の履歴および更新したQを出力
def goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi_0):
    s = 0  # スタート地点
    s_a_history = [[0, np.nan]]  # エージェントの移動を記録するリスト
 
    while (1):  # ゴールするまでループ
        [a, s_next] = get_action_and_s_next(s, Q, epsilon, pi_0)
        s_a_history[-1][1] = a
        # 現在の状態（つまり一番最後なのでindex=-1）に行動を代入
 
        s_a_history.append([s_next, np.nan])
        # 次の状態を代入。行動はまだ分からないのでnanにしておく
 
        # 報酬を与え,　次の行動を求めます
        if s_next == 8:
            r = 1  # ゴールにたどり着いたなら報酬を与える
            a_next = np.nan
        else:
            r = 0
 
        # 価値関数を更新
        Q = Q_learning(s, a, r, s_next, Q, eta, gamma)
 
        # 終了判定
        if s_next == 8:  # ゴール地点なら終了
            break
        else:
            s = s_next
 
    return [s_a_history, Q]

# %%
# 初期の行動価値関数Qを設定
[a, b] = theta_0.shape  # 行と列の数をa, bに格納
Q = np.random.rand(a, b) * theta_0 * 0.1
# *theta0をすることで要素ごとに掛け算をし、Qの壁方向の値がnanになる

# %% [markdown]
# # 迷路を解く

# %%
# Q学習で迷路を解く
eta = 0.1  # 学習率
gamma = 0.9  # 時間割引率
epsilon = 0.5  # ε-greedy法の初期値
v = np.nanmax(Q, axis=1)  # 状態ごとに価値の最大値を求める
is_continue = True
episode = 1
 
V=[] # エピソードごとの状態価値を格納する
V.append(np.nanmax(Q, axis=1))  # 状態ごとに行動価値の最大値を求める
 
while is_continue:  # is_continueがFalseになるまで繰り返す
    print("エピソード:" + str(episode))
 
    # ε-greedyの値を少しずつ小さくする
    epsilon = epsilon / 2
 
    # Q学習で迷路を解き、移動した履歴と更新したQを求める
    [s_a_history, Q] = goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi_0)
 
    # 状態価値の変化
    new_v = np.nanmax(Q, axis=1)  # 状態ごとに行動価値の最大値を求める
    print(np.sum(np.abs(new_v - v)))  # 状態価値関数の変化を出力
    v = new_v
    V.append(v) # このエピソード終了時の状態価値関数を追加
 
    print("迷路を解くのにかかったステップ数は" + str(len(s_a_history) - 1) + "です")
 
    # 100エピソード繰り返す
    episode = episode + 1
    if episode > 100:
        break
# Out:
# エピソード:1
# 0.22833817707095183
# 迷路を解くのにかかったステップ数は246です
# エピソード:2
# 0.11972541743097495
# 迷路を解くのにかかったステップ数は50です
# エピソード:3
# 0.1270015040858692
# 迷路を解くのにかかったステップ数は224です
# エピソード:4
# 0.09226244955587257
# 迷路を解くのにかかったステップ数は4です
# エピソード:5
# 0.0911898819277001
# 迷路を解くのにかかったステップ数は4です
# エピソード:6
# 0.0901386725262685
# 迷路を解くのにかかったステップ数は4です
# エピソード:7
# 0.08909032309167292
# 迷路を解くのにかかったステップ数は4です
# エピソード:8
# 0.08802751719992326
# 迷路を解くのにかかったステップ数は4です
# エピソード:9
# 0.0869347792480279
# 迷路を解くのにかかったステップ数は4です
# エピソード:10
# 0.08579887079210714
# 迷路を解くのにかかったステップ数は4です
# エピソード:11
# 0.0846089868806997
# 迷路を解くのにかかったステップ数は4です
# エピソード:12
# 0.08335680297325793
# 迷路を解くのにかかったステップ数は4です
# エピソード:13
# 0.0820364130286812
# 迷路を解くのにかかったステップ数は4です
# エピソード:14
# 0.08064419107063779
# 迷路を解くのにかかったステップ数は4です
# エピソード:15
# 0.07917860171249838
# 迷路を解くのにかかったステップ数は4です
# エピソード:16
# 0.0776399795225742
# 迷路を解くのにかかったステップ数は4です
# エピソード:17
# 0.07603029253238726
# 迷路を解くのにかかったステップ数は4です
# エピソード:18
# 0.07435290146908337
# 迷路を解くのにかかったステップ数は4です
# エピソード:19
# 0.07261232328555413
# 迷路を解くのにかかったステップ数は4です
# エピソード:20
# 0.07081400514792996
# 迷路を解くのにかかったステップ数は4です
# エピソード:21
# 0.06896411311810269
# 迷路を解くのにかかったステップ数は4です
# エピソード:22
# 0.06706933825304037
# 迷路を解くのにかかったステップ数は4です
# エピソード:23
# 0.06513672166067777
# 迷路を解くのにかかったステップ数は4です
# エピソード:24
# 0.06317349914349468
# 迷路を解くのにかかったステップ数は4です
# エピソード:25
# 0.06118696537476509
# 迷路を解くのにかかったステップ数は4です
# エピソード:26
# 0.059184357046486974
# 迷路を解くのにかかったステップ数は4です
# エピソード:27
# 0.05717275406685457
# 迷路を解くのにかかったステップ数は4です
# エピソード:28
# 0.05515899763951765
# 迷路を解くのにかかったステップ数は4です
# エピソード:29
# 0.05314962390252348
# 迷路を解くのにかかったステップ数は4です
# エピソード:30
# 0.051150811721775935
# 迷路を解くのにかかったステップ数は4です
# エピソード:31
# 0.04916834320570007
# 迷路を解くのにかかったステップ数は4です
# エピソード:32
# 0.047207575521159784
# 迷路を解くのにかかったステップ数は4です
# エピソード:33
# 0.04527342263472567
# 迷路を解くのにかかったステップ数は4です
# エピソード:34
# 0.04337034566934056
# 迷路を解くのにかかったステップ数は4です
# エピソード:35
# 0.04150235064730112
# 迷路を解くのにかかったステップ数は4です
# エピソード:36
# 0.039672992480715985
# 迷路を解くのにかかったステップ数は4です
# エピソード:37
# 0.03788538416584769
# 迷路を解くのにかかったステップ数は4です
# エピソード:38
# 0.036142210234647754
# 迷路を解くのにかかったステップ数は4です
# エピソード:39
# 0.03444574361278563
# 迷路を解くのにかかったステップ数は4です
# エピソード:40
# 0.032797865126654446
# 迷路を解くのにかかったステップ数は4です
# エピソード:41
# 0.03120008499083804
# 迷路を解くのにかかったステップ数は4です
# エピソード:42
# 0.029653565691406425
# 迷路を解くのにかかったステップ数は4です
# エピソード:43
# 0.028159145758566373
# 迷路を解くのにかかったステップ数は4です
# エピソード:44
# 0.026717363994289645
# 迷路を解くのにかかったステップ数は4です
# エピソード:45
# 0.025328483786461742
# 迷路を解くのにかかったステップ数は4です
# エピソード:46
# 0.02399251720086304
# 迷路を解くのにかかったステップ数は4です
# エピソード:47
# 0.02270924859605583
# 迷路を解くのにかかったステップ数は4です
# エピソード:48
# 0.02147825755427546
# 迷路を解くのにかかったステップ数は4です
# エピソード:49
# 0.02029894096397966
# 迷路を解くのにかかったステップ数は4です
# エピソード:50
# 0.019170534127160854
# 迷路を解くのにかかったステップ数は4です
# エピソード:51
# 0.018092130797232042
# 迷路を解くのにかかったステップ数は4です
# エピソード:52
# 0.01706270208163896
# 迷路を解くのにかかったステップ数は4です
# エピソード:53
# 0.016081114167686317
# 迷路を解くのにかかったステップ数は4です
# エピソード:54
# 0.0151461448508039
# 迷路を解くのにかかったステップ数は4です
# エピソード:55
# 0.014256498861933253
# 迷路を解くのにかかったステップ数は4です
# エピソード:56
# 0.013410822005263445
# 迷路を解くのにかかったステップ数は4です
# エピソード:57
# 0.012607714129477587
# 迷路を解くのにかかったステップ数は4です
# エピソード:58
# 0.011845740965323981
# 迷路を解くのにかかったステップ数は4です
# エピソード:59
# 0.011123444869939103
# 迷路を解くのにかかったステップ数は4です
# エピソード:60
# 0.01043935452420941
# 迷路を解くのにかかったステップ数は4です
# エピソード:61
# 0.009791993633784468
# 迷路を解くのにかかったステップ数は4です
# エピソード:62
# 0.009179888687359528
# 迷路を解くのにかかったステップ数は4です
# エピソード:63
# 0.00860157582772958
# 迷路を解くのにかかったステップ数は4です
# エピソード:64
# 0.008055606892040768
# 迷路を解くのにかかったステップ数は4です
# エピソード:65
# 0.0075405546777953525
# 迷路を解くのにかかったステップ数は4です
# エピソード:66
# 0.0070550174906282015
# 迷路を解くのにかかったステップ数は4です
# エピソード:67
# 0.00659762302879352
# 迷路を解くのにかかったステップ数は4です
# エピソード:68
# 0.006167031657786648
# 迷路を解くのにかかったステップ数は4です
# エピソード:69
# 0.005761939126666227
# 迷路を解くのにかかったステップ数は4です
# エピソード:70
# 0.005381078775515524
# 迷路を解くのにかかったステップ数は4です
# エピソード:71
# 0.005023223281173106
# 迷路を解くのにかかったステップ数は4です
# エピソード:72
# 0.004687185985901898
# 迷路を解くのにかかったステップ数は4です
# エピソード:73
# 0.004371821851143709
# 迷路を解くのにかかったステップ数は4です
# エピソード:74
# 0.004076028075918781
# 迷路を解くのにかかったステップ数は4です
# エピソード:75
# 0.003798744416861566
# 迷路を解くのにかかったステップ数は4です
# エピソード:76
# 0.0035389532443212968
# 迷路を解くのにかかったステップ数は4です
# エピソード:77
# 0.0032956793664530304
# 迷路を解くのにかかったステップ数は4です
# エピソード:78
# 0.0030679896507876947
# 迷路を解くのにかかったステップ数は4です
# エピソード:79
# 0.0028549924704114327
# 迷路を解くのにかかったステップ数は4です
# エピソード:80
# 0.0026558369996315667
# 迷路を解くのにかかったステップ数は4です
# エピソード:81
# 0.002469712381840794
# 迷路を解くのにかかったステップ数は4です
# エピソード:82
# 0.002295846790255185
# 迷路を解くのにかかったステップ数は4です
# エピソード:83
# 0.0021335064002614423
# 迷路を解くのにかかったステップ数は4です
# エピソード:84
# 0.001981994290290112
# 迷路を解くのにかかったステップ数は4です
# エピソード:85
# 0.0018406492864325719
# 迷路を解くのにかかったステップ数は4です
# エピソード:86
# 0.001708844764423123
# 迷路を解くのにかかったステップ数は4です
# エピソード:87
# 0.0015859874211352487
# 迷路を解くのにかかったステップ数は4です
# エピソード:88
# 0.0014715160263686355
# 迷路を解くのにかかったステップ数は4です
# エピソード:89
# 0.0013649001644391312
# 迷路を解くのにかかったステップ数は4です
# エピソード:90
# 0.0012656389739218454
# 迷路を解くのにかかったステップ数は4です
# エピソード:91
# 0.0011732598928284599
# 迷路を解くのにかかったステップ数は4です
# エピソード:92
# 0.0010873174155261456
# 迷路を解くのにかかったステップ数は4です
# エピソード:93
# 0.0010073918668156434
# 迷路を解くのにかかったステップ数は4です
# エピソード:94
# 0.0009330881977772654
# 迷路を解くのにかかったステップ数は4です
# エピソード:95
# 0.0008640348072627146
# 迷路を解くのにかかったステップ数は4です
# エピソード:96
# 0.0007998823922567011
# 迷路を解くのにかかったステップ数は4です
# エピソード:97
# 0.0007403028297278125
# 迷路を解くのにかかったステップ数は4です
# エピソード:98
# 0.0006849880920690721
# 迷路を解くのにかかったステップ数は4です
# エピソード:99
# 0.0006336491977467773
# 迷路を解くのにかかったステップ数は4です
# エピソード:100
# 0.0005860151983595463
# 迷路を解くのにかかったステップ数は4です

# %% [markdown]
# # 可視化

# %%
# 状態価値の変化を可視化します
# 参考URL http://louistiao.me/posts/notebooks/embedding-matplotlib-animations-in-jupyter-notebooks/
from matplotlib import animation
from IPython.display import HTML
import matplotlib.cm as cm  # color map
 
def init():
    # 背景画像の初期化
    line.set_data([], [])
    return (line,)
 
def animate(i):
    # フレームごとの描画内容
    # 各マスに状態価値の大きさに基づく色付きの四角を描画
    line, = ax.plot([0.5], [2.5], marker="s",
                    color=cm.jet(V[i][0]), markersize=85)  # S0
    line, = ax.plot([1.5], [2.5], marker="s",
                    color=cm.jet(V[i][1]), markersize=85)  # S1
    line, = ax.plot([2.5], [2.5], marker="s",
                    color=cm.jet(V[i][2]), markersize=85)  # S2
    line, = ax.plot([0.5], [1.5], marker="s",
                    color=cm.jet(V[i][3]), markersize=85)  # S3
    line, = ax.plot([1.5], [1.5], marker="s",
                    color=cm.jet(V[i][4]), markersize=85)  # S4
    line, = ax.plot([2.5], [1.5], marker="s",
                    color=cm.jet(V[i][5]), markersize=85)  # S5
    line, = ax.plot([0.5], [0.5], marker="s",
                    color=cm.jet(V[i][6]), markersize=85)  # S6
    line, = ax.plot([1.5], [0.5], marker="s",
                    color=cm.jet(V[i][7]), markersize=85)  # S7
    line, = ax.plot([2.5], [0.5], marker="s",
                    color=cm.jet(1.0), markersize=85)  # S8
    return (line,)
 
#　初期化関数とフレームごとの描画関数を用いて動画を作成
anim = animation.FuncAnimation(
    fig, animate, init_func=init, frames=len(V), interval=200, repeat=False)
 
HTML(anim.to_html5_video())
# Out:
# <video width="360" height="360" controls autoplay>
#   <source type="video/mp4" src="...
