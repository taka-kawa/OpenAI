# %%
# Jupyterでmatplotlibを使用する宣言と、使用するライブラリの定義
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# 初期位置での迷路の様子

# 図を描く大きさと、図の変数名を宣言
fig = plt.figure(figsize=(5, 5))
ax = plt.gca()

# 赤い壁を描く
plt.plot([1, 1], [0, 1], color='red', linewidth=2)
plt.plot([1, 2], [2, 2], color='red', linewidth=2)
plt.plot([2, 2], [2, 1], color='red', linewidth=2)
plt.plot([2, 3], [1, 1], color='red', linewidth=2)

# 状態を示す文字S0～S8を描く
plt.text(0.5, 2.5, 'S0', size=14, ha='center')
plt.text(1.5, 2.5, 'S1', size=14, ha='center')
plt.text(2.5, 2.5, 'S2', size=14, ha='center')
plt.text(0.5, 1.5, 'S3', size=14, ha='center')
plt.text(1.5, 1.5, 'S4', size=14, ha='center')
plt.text(2.5, 1.5, 'S5', size=14, ha='center')
plt.text(0.5, 0.5, 'S6', size=14, ha='center')
plt.text(1.5, 0.5, 'S7', size=14, ha='center')
plt.text(2.5, 0.5, 'S8', size=14, ha='center')
plt.text(0.5, 2.3, 'START', ha='center')
plt.text(2.5, 0.3, 'GOAL', ha='center')

# 描画範囲の設定と目盛りを消す設定
ax.set_xlim(0, 3)
ax.set_ylim(0, 3)
plt.tick_params(axis='both', which='both', bottom='off', top='off',
                labelbottom='off', right='off', left='off', labelleft='off')

# 現在値S0に緑丸を描画する
line, = ax.plot([0.5], [2.5], marker="o", color='g', markersize=60)

plt.show()

# %%
# 初期の方策を決定するパラメータtheta_0を設定
# 行は状態0～7、列は移動方向で↑、→、↓、←を表す
theta_0 = np.array([[np.nan, 1, 1, np.nan],  # s0
                    [np.nan, 1, np.nan, 1],  # s1
                    [np.nan, np.nan, 1, 1],  # s2
                    [1, 1, 1, np.nan],  # s3
                    [np.nan, np.nan, 1, 1],  # s4
                    [1, np.nan, np.nan, np.nan],  # s5
                    [1, np.nan, np.nan, np.nan],  # s6
                    [1, 1, np.nan, np.nan],  # s7、※s8はゴールなので、方策はなし
                    ])


# 初期の行動価値関数Qを設定
[a, b] = theta_0.shape  # 行と列の数をa, bに格納
Q = np.random.rand(a, b) * theta_0
# *theta0をすることで要素ごとに掛け算をし、壁方向がnanになる

# %%
Q
# Out:
# array([[       nan, 0.38211031, 0.18495244,        nan],
#        [       nan, 0.34036152,        nan, 0.98002268],
#        [       nan,        nan, 0.99435842, 0.67295702],
#        [0.16015922, 0.82306795, 0.81085304,        nan],
#        [       nan,        nan, 0.76777271, 0.97274908],
#        [0.5023038 ,        nan,        nan,        nan],
#        [0.45491322,        nan,        nan,        nan],
#        [0.47452561, 0.89584607,        nan,        nan]])

# %% [markdown]
# # 方策をε-greedy法で表現

# %%
# 方策パラメータtheta_0をランダム方策piに変換する関数の定義
def simple_convert_into_pi_from_theta(theta):
    '''単純に割合を計算する'''
 
    [m, n] = theta.shape  # thetaの行列サイズを取得
    pi = np.zeros((m, n))
    for i in range(0, m):
        pi[i, :] = theta[i, :] / np.nansum(theta[i, :])  # 割合の計算
 
    pi = np.nan_to_num(pi)  # nanを0に変換
 
    return pi
 
# ランダム行動方策pi_0を求める
pi_0 = simple_convert_into_pi_from_theta(theta_0)

# ε-greedy法を実装
def get_action_and_s_next(s, Q, epsilon, pi_0):
    direction = ["up", "right", "down", "left"]
 
    # 行動を決める
    if np.random.rand() < epsilon:
        # εの確率でランダムに動く
        next_direction = np.random.choice(direction, p=pi_0[s, :])
    else:
        # Qの最大値の行動を採用する
        next_direction = direction[np.nanargmax(Q[s, :])]
 
    # 決めた行動で次の状態を決める
    if next_direction == "up":
        action = 0
        s_next = s - 3  # 上に移動するときは状態の数字が3小さくなる
    elif next_direction == "right":
        action = 1
        s_next = s + 1  # 右に移動するときは状態の数字が1大きくなる
    elif next_direction == "down":
        action = 2
        s_next = s + 3  # 下に移動するときは状態の数字が3大きくなる
    elif next_direction == "left":
        action = 3
        s_next = s - 1  # 左に移動するときは状態の数字が1小さくなる
 
    return [action, s_next]

# %% [markdown]
# # Sarsaによる行動価値関数の更新
# $$Q(s_t,a_t) = Q(s_t,a_t) + η * (R_{t+1} + γQ(s_{t+1},a_{t+1}) - Q(s_t,a_t))$$

# %%
# Sarsaによる行動価値関数Qの更新
def Sarsa(s, a, r, s_next, a_next, Q, eta, gamma):
 
    if s_next == 8:  # ゴールした場合
        Q[s, a] = Q[s, a] + eta * (r - Q[s, a])
 
    else:
        Q[s, a] = Q[s, a] + eta * (r + gamma * Q[s_next, a_next] - Q[s, a])
 
    return Q

# %% [markdown]
# サンプリングして平均とかは取ってない

# %%
# Sarsaで迷路を解く関数の定義、状態と行動の履歴および更新したQを出力
def goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi_0):
    s = 0  # スタート地点
    s_a_history = [[0, np.nan]]  # エージェントの移動を記録するリスト
 
    while (1):  # ゴールするまでループ
        [a, s_next] = get_action_and_s_next(s, Q, epsilon, pi_0)
        s_a_history[-1][1] = a
        # 現在の状態（つまり一番最後なのでindex=-1）に行動を代入
 
        s_a_history.append([s_next, np.nan])
        # 次の状態を代入。行動はまだ分からないのでnanにしておく
 
        # 報酬を与え,　次の行動を求めます
        if s_next == 8:
            r = 1  # ゴールにたどり着いたなら報酬を与える
            a_next = np.nan
        else:
            r = 0
            [a_next, _] = get_action_and_s_next(s_next, Q, epsilon, pi_0)
            # 実際行動しないですが、次の行動a_nextを求めます。
            # 返り値の_は、その変数は無視するという意味です
 
        # 価値関数を更新
        Q = Sarsa(s, a, r, s_next, a_next, Q, eta, gamma)
 
        # 終了判定
        if s_next == 8:  # ゴール地点なら終了
            break
        else:
            s = s_next
    return [s_a_history, Q]

# %%
# Sarsaで迷路を解く
eta = 0.1  # 学習率
gamma = 0.9  # 時間割引率
epsilon = 0.5  # ε-greedy法の初期値
v = np.nanmax(Q, axis=1)  # 状態ごとに価値の最大値を求める
is_continue = True
episode = 1
 
while is_continue:  # is_continueがFalseになるまで繰り返す
    print("エピソード:" + str(episode))
 
    # ε-greedyの値を少しずつ小さくする
    epsilon = epsilon / 2
 
    # Sarsaで迷路を解き、移動した履歴と更新したQを求める
    [s_a_history, Q] = goal_maze_ret_s_a_Q(Q, epsilon, eta, gamma, pi_0)
 
    # 状態価値の変化
    new_v = np.nanmax(Q, axis=1)  # 状態ごとに価値の最大値を求める
    print(np.sum(np.abs(new_v - v)))  # 状態価値の変化を出力
    v = new_v
 
    print("迷路を解くのにかかったステップ数は" + str(len(s_a_history) - 1) + "です")
 
    # 100エピソード繰り返す
    episode = episode + 1
    if episode > 100:
        break
# Out:
# エピソード:1
# 0.8626147728121039
# 迷路を解くのにかかったステップ数は56です
# エピソード:2
# 0.032571681503407834
# 迷路を解くのにかかったステップ数は6です
# エピソード:3
# 1.297561019306356
# 迷路を解くのにかかったステップ数は324です
# エピソード:4
# 0.042820021663342256
# 迷路を解くのにかかったステップ数は10です
# エピソード:5
# 0.04171716312325374
# 迷路を解くのにかかったステップ数は4です
# エピソード:6
# 0.03749850902262464
# 迷路を解くのにかかったステップ数は4です
# エピソード:7
# 0.033693657615398886
# 迷路を解くのにかかったステップ数は4です
# エピソード:8
# 0.030268292203503577
# 迷路を解くのにかかったステップ数は4です
# エピソード:9
# 0.027736977619584824
# 迷路を解くのにかかったステップ数は4です
# エピソード:10
# 0.02586334538083246
# 迷路を解くのにかかったステップ数は4です
# エピソード:11
# 0.024165859226265796
# 迷路を解くのにかかったステップ数は4です
# エピソード:12
# 0.022623415780771428
# 迷路を解くのにかかったステップ数は4です
# エピソード:13
# 0.021217505085423527
# 迷路を解くのにかかったステップ数は4です
# エピソード:14
# 0.019931922212402364
# 迷路を解くのにかかったステップ数は4です
# エピソード:15
# 0.018752505427866772
# 迷路を解くのにかかったステップ数は4です
# エピソード:16
# 0.017666899323375618
# 迷路を解くのにかかったステップ数は4です
# エピソード:17
# 0.01666434126953864
# 迷路を解くのにかかったステップ数は4です
# エピソード:18
# 0.015735469522835888
# 迷路を解くのにかかったステップ数は4です
# エピソード:19
# 0.014872151327991578
# 迷路を解くのにかかったステップ数は4です
# エピソード:20
# 0.014067329395694661
# 迷路を解くのにかかったステップ数は4です
# エピソード:21
# 0.013314885192107662
# 迷路を解くのにかかったステップ数は4です
# エピソード:22
# 0.01260951754700157
# 迷路を解くのにかかったステップ数は4です
# エピソード:23
# 0.011946635167113251
# 迷路を解くのにかかったステップ数は4です
# エピソード:24
# 0.011322261726850358
# 迷路を解くのにかかったステップ数は4です
# エピソード:25
# 0.010732952297005993
# 迷路を解くのにかかったステップ数は4です
# エピソード:26
# 0.010175719961443175
# 迷路を解くのにかかったステップ数は4です
# エピソード:27
# 0.009647971560099111
# 迷路を解くのにかかったステップ数は4です
# エピソード:28
# 0.009147451582825594
# 迷路を解くのにかかったステップ数は4です
# エピソード:29
# 0.008672193321593413
# 迷路を解くのにかかったステップ数は4です
# エピソード:30
# 0.008220476467750037
# 迷路を解くのにかかったステップ数は4です
# エピソード:31
# 0.007790790415894366
# 迷路を解くのにかかったステップ数は4です
# エピソード:32
# 0.007381802606229115
# 迷路を解くのにかかったステップ数は4です
# エピソード:33
# 0.006992331302839938
# 迷路を解くのにかかったステップ数は4です
# エピソード:34
# 0.0066213222662073745
# 迷路を解くのにかかったステップ数は4です
# エピソード:35
# 0.0062678288344404365
# 迷路を解くのにかかったステップ数は4です
# エピソード:36
# 0.0059309949793519
# 迷路を解くのにかかったステップ数は4です
# エピソード:37
# 0.005610040950753459
# 迷路を解くのにかかったステップ数は4です
# エピソード:38
# 0.00530425116543265
# 迷路を解くのにかかったステップ数は4です
# エピソード:39
# 0.005012964036408829
# 迷路を解くのにかかったステップ数は4です
# エピソード:40
# 0.00473556347351356
# 迷路を解くのにかかったステップ数は4です
# エピソード:41
# 0.00447147181831431
# 迷路を解くのにかかったステップ数は4です
# エピソード:42
# 0.004220144005183113
# 迷路を解くのにかかったステップ数は4です
# エピソード:43
# 0.003981062766129861
# 迷路を解くのにかかったステップ数は4です
# エピソード:44
# 0.003753734720109314
# 迷路を解くのにかかったステップ数は4です
# エピソード:45
# 0.0035376872081207544
# 迷路を解くのにかかったステップ数は4です
# エピソード:46
# 0.003332465753737246
# 迷路を解くのにかかったステップ数は4です
# エピソード:47
# 0.003137632044968197
# 迷路を解くのにかかったステップ数は4です
# エピソード:48
# 0.002952762347738891
# 迷路を解くのにかかったステップ数は4です
# エピソード:49
# 0.002777446273964812
# 迷路を解くのにかかったステップ数は4です
# エピソード:50
# 0.0026112858383616766
# 迷路を解くのにかかったステップ数は4です
# エピソード:51
# 0.002453894747936669
# 迷路を解くのにかかったステップ数は4です
# エピソード:52
# 0.0023048978766639916
# 迷路を解くのにかかったステップ数は4です
# エピソード:53
# 0.002163930885332843
# 迷路を解くのにかかったステップ数は4です
# エピソード:54
# 0.002030639953044644
# 迷路を解くのにかかったステップ数は4です
# エピソード:55
# 0.0019046815924745886
# 迷路を解くのにかかったステップ数は4です
# エピソード:56
# 0.001785722525863065
# 迷路を解くのにかかったステップ数は4です
# エピソード:57
# 0.0016734396028915688
# 迷路を解くのにかかったステップ数は4です
# エピソード:58
# 0.0015675197451783252
# 迷路を解くのにかかったステップ数は4です
# エピソード:59
# 0.0014676599051832717
# 迷路を解くのにかかったステップ数は4です
# エピソード:60
# 0.0013735670299062086
# 迷路を解くのにかかったステップ数は4です
# エピソード:61
# 0.0012849580219543855
# 迷路を解くのにかかったステップ数は4です
# エピソード:62
# 0.0012015596923946603
# 迷路を解くのにかかったステップ数は4です
# エピソード:63
# 0.001123108701337694
# 迷路を解くのにかかったステップ数は4です
# エピソード:64
# 0.0010493514834762907
# 迷路を解くのにかかったステップ数は4です
# エピソード:65
# 0.0009800441568308393
# 迷路を解くのにかかったステップ数は4です
# エピソード:66
# 0.0009149524138173382
# 迷路を解くのにかかったステップ数は4です
# エピソード:67
# 0.0008538513944138515
# 迷路を解くのにかかったステップ数は4です
# エピソード:68
# 0.0007965255417473616
# 迷路を解くのにかかったステップ数は4です
# エピソード:69
# 0.0007427684408339852
# 迷路を解くのにかかったステップ数は4です
# エピソード:70
# 0.0006923826415151657
# 迷路を解くのにかかったステップ数は4です
# エピソード:71
# 0.0006451794668618227
# 迷路を解くのにかかったステップ数は4です
# エピソード:72
# 0.0006009788084704315
# 迷路を解くのにかかったステップ数は4です
# エピソード:73
# 0.0005596089101724822
# 迷路を解くのにかかったステップ数は4です
# エピソード:74
# 0.0005209061417248417
# 迷路を解くのにかかったステップ数は4です
# エピソード:75
# 0.00048471476406342084
# 迷路を解くのにかかったステップ数は4です
# エピソード:76
# 0.0004508866876710149
# 迷路を解くのにかかったステップ数は4です
# エピソード:77
# 0.0004192812255731093
# 迷路を解くのにかかったステップ数は4です
# エピソード:78
# 0.00038976484240482723
# 迷路を解くのにかかったステップ数は4です
# エピソード:79
# 0.0003622109009189245
# 迷路を解くのにかかったステップ数は4です
# エピソード:80
# 0.0003364994072112548
# 迷路を解くのにかかったステップ数は4です
# エピソード:81
# 0.00031251675584820227
# 迷路を解くのにかかったステップ数は4です
# エピソード:82
# 0.0002901554759843217
# 迷路を解くのにかかったステップ数は4です
# エピソード:83
# 0.00026931397945695323
# 迷路を解くのにかかったステップ数は4です
# エピソード:84
# 0.000249896311743103
# 迷路を解くのにかかったステップ数は4です
# エピソード:85
# 0.00023181190657239892
# 迷路を解くのにかかったステップ数は4です
# エピソード:86
# 0.00021497534489278713
# 迷路を解くのにかかったステップ数は4です
# エピソード:87
# 0.00019930611879281912
# 迷路を解くのにかかったステップ数は4です
# エピソード:88
# 0.00018472840090633103
# 迷路を解くのにかかったステップ数は4です
# エピソード:89
# 0.00017117081973394566
# 迷路を解くのにかかったステップ数は4です
# エピソード:90
# 0.0001585662412540989
# 迷路を解くのにかかったステップ数は4です
# エピソード:91
# 0.00014685155711025022
# 迷路を解くのにかかったステップ数は4です
# エピソード:92
# 0.00013596747961153177
# 迷路を解くのにかかったステップ数は4です
# エピソード:93
# 0.00012585834371514615
# 迷路を解くのにかかったステップ数は4です
# エピソード:94
# 0.00011647191610919538
# 迷路を解くのにかかったステップ数は4です
# エピソード:95
# 0.0001077592114648862
# 迷路を解くのにかかったステップ数は4です
# エピソード:96
# 9.967431588298048e-05
# 迷路を解くのにかかったステップ数は4です
# エピソード:97
# 9.217421752227839e-05
# 迷路を解くのにかかったステップ数は4です
# エピソード:98
# 8.52186443609515e-05
# 迷路を解くのにかかったステップ数は4です
# エピソード:99
# 7.876990901478642e-05
# 迷路を解くのにかかったステップ数は4です
# エピソード:100
# 7.279276050187189e-05
# 迷路を解くのにかかったステップ数は4です

# %%
# エージェントの移動の様子を可視化します
# 参考URL http://louistiao.me/posts/notebooks/embedding-matplotlib-animations-in-jupyter-notebooks/
from matplotlib import animation
from IPython.display import HTML

def init():
    # 背景画像の初期化
    line.set_data([], [])
    return (line,)
 
def animate(i):
    # フレームごとの描画内容
    state = s_a_history[i][0]  # 現在の場所を描く
    x = (state % 3) + 0.5  # 状態のx座標は、3で割った余り+0.5
    y = 2.5 - int(state / 3)  # y座標は3で割った商を2.5から引く
    line.set_data(x, y)
    return (line,)
 
#　初期化関数とフレームごとの描画関数を用いて動画を作成
anim = animation.FuncAnimation(fig, animate, init_func=init, frames=len(
    s_a_history), interval=200, repeat=False)
 
HTML(anim.to_html5_video())
# Out:
# <video width="360" height="360" controls autoplay>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>

# %%
s_a_history
# Out:
# [[0, 2], [3, 1], [4, 2], [7, 1], [8, nan]]
